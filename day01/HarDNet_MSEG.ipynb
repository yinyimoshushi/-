# %% [markdown]
# <a href="https://colab.research.google.com/github/yinyimoshushi/deeplearning/blob/master/day01/HarDNet_MSEG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/james128333/HarDNet-MSEG
# Out:
# Cloning into 'HarDNet-MSEG'...
# remote: Enumerating objects: 1120, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1120 (delta 0), reused 0 (delta 0), pack-reused 1117
# Receiving objects: 100% (1120/1120), 12.92 MiB | 17.20 MiB/s, done.
# Resolving deltas: 100% (241/241), done.

# %%
import torch
torch.cuda.get_device_name()
# Out:
# 'Tesla T4'

# %%
# !pwd
# Out:
# /content/drive/My Drive/HarDNet-MSEG

# %%
# %cd /content/
# Out:
# /content

# %%
# !cp ./drive/MyDrive/hardnet85.pth ./HarDNet-MSEG/lib

# %%
# !cp ./drive/MyDrive/Kvasir_SEG_Training_880.zip ./HarDNet-MSEG/data

# %%
# !cp ./drive/MyDrive/Kvasir_SEG_Validation_120.zip ./HarDNet-MSEG/data

# %%
# !unzip -d ./HarDNet-MSEG/data ./HarDNet-MSEG/data/Kvasir_SEG_Training_880.zip
# Out:
# Archive:  ./HarDNet-MSEG/data/Kvasir_SEG_Training_880.zip
#    creating: ./HarDNet-MSEG/data/Kvasir_SEG_Training_880/
#    creating: ./HarDNet-MSEG/data/Kvasir_SEG_Training_880/image/
#   inflating: ./HarDNet-MSEG/data/Kvasir_SEG_Training_880/image/cju0qkwl35piu0993l0dewei2.png
#   inflating: ./HarDNet-MSEG/data/Kvasir_SEG_Training_880/image/cju0qoxqj9q6s0835b43399p4.png
#   inflating: ./HarDNet-MSEG/data/Kvasir_SEG_Training_880/image/cju0qx73cjw570799j4n5cjze.png
#   inflating: ./HarDNet-MSEG/data/Kvasir_SEG_Training_880/image/cju0roawvklrq0799vmjorwfv.png
#   inflating: ./HarDNet-MSEG/data/Kvasir_SEG_Training_880/image/cju0rx1idathl0835detmsp84.png
#   inflating: ./HarDNet-MSEG/data/Kvasir_SEG_Training_880/image/cju0s2a9ekvms080138tjjpxr.png
#   inflating: ./HarDNet-MSEG/data/Kvasir_SEG_Training_880/image/cju171py4qiha0835u8sl59ds.png
#   inflating: ./HarDNet-MSEG/data/Kvasir_SEG_Training_880/image/cju175facms5f0993a5tjikvt.png
# ...

# %%
# !unzip -d ./HarDNet-MSEG/data ./HarDNet-MSEG/data/Kvasir_SEG_Validation_120.zip
# Out:
# Archive:  ./HarDNet-MSEG/data/Kvasir_SEG_Validation_120.zip
# replace ./HarDNet-MSEG/data/Kvasir_SEG_Validation_120/images/cju0s690hkp960855tjuaqvv0.png? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# %cd HarDNet-MSEG/
# Out:
# /content/HarDNet-MSEG

# %%
# !pip install thop

# %%
# !pip install torchstat

# %%
# !wget https://github.com/PingoLH/Pytorch-HarDNet/blob/master/hardnet68.pth
# Out:
# --2021-07-27 06:34:25--  https://github.com/PingoLH/Pytorch-HarDNet/blob/master/hardnet68.pth
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘hardnet68.pth’
#
# hardnet68.pth           [ <=>                ] 112.58K  --.-KB/s    in 0.02s
#
# 2021-07-27 06:34:26 (4.76 MB/s) - ‘hardnet68.pth’ saved [115277]

# %%
# !git clone https://github.com/PingoLH/Pytorch-HarDNet
# Out:
# Cloning into 'Pytorch-HarDNet'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (104/104), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 168 (delta 44), reused 90 (delta 32), pack-reused 64
# Receiving objects: 100% (168/168), 197.06 MiB | 32.09 MiB/s, done.
# Resolving deltas: 100% (67/67), done.

# %%
# !cp Pytorch-HarDNet/hardnet68.pth ./

# %%
# %cd drive/MyDrive/HarDNet-MSEG/
# Out:
# /content/drive/MyDrive/HarDNet-MSEG

# %%
import torch
torch.cuda.get_device_name()
# Out:
# 'Tesla K80'

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Thu Aug 19 01:38:04 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !cp ../drive/MyDrive/data.zip ./

# %%
# !unzip data.zip
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: data/TrainDataset/masks/cju2lcyfgkf5809932fn9gucn.png
#   inflating: __MACOSX/data/TrainDataset/masks/._cju2lcyfgkf5809932fn9gucn.png
#   inflating: data/TrainDataset/masks/517.png
#   inflating: __MACOSX/data/TrainDataset/masks/._517.png
#   inflating: data/TrainDataset/masks/cju7dqcwi2dz00850gcmr2ert.png
#   inflating: __MACOSX/data/TrainDataset/masks/._cju7dqcwi2dz00850gcmr2ert.png
#   inflating: data/TrainDataset/masks/271.png
#   inflating: __MACOSX/data/TrainDataset/masks/._271.png
#   inflating: data/TrainDataset/masks/cju8dn0c3u2v50801k8rvq02f.png
#   inflating: __MACOSX/data/TrainDataset/masks/._cju8dn0c3u2v50801k8rvq02f.png
#   inflating: data/TrainDataset/masks/265.png
#   inflating: __MACOSX/data/TrainDataset/masks/._265.png
#   inflating: data/TrainDataset/masks/503.png
#   inflating: __MACOSX/data/TrainDataset/masks/._503.png
#   inflating: data/TrainDataset/masks/cju88v2f9oi8w0871hx9auh01.png
# ...

# %%
# !cp -r ./drive/MyDrive/HarDNet-MSEG/ ./

# %%
# !python Train.py --train_path ./data/TrainDataset --test_path ./data/TestDataset/Kvasir
# Out:
# 68 LOADED
# 68 LOADED READY
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 0
# )
# True
# Using RandomRotation, RandomFlip
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:1231: UserWarning: Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead
#   "Argument resample is deprecated and will be removed since v0.10.0. Please, use interpolation instead"
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %%
# !pip install scipy==1.2.1
# Out:
# ...
#      |████████████████████████████████| 24.8 MB 64 kB/s
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...

# %%
# !python Test.py --pth_path ./snapshots/HarD-MSEG-best/80HarD-MSEG-best.pth
# Out:
# 68 LOADED
# 68 LOADED READY
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3613: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode)
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3487: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
# ...

# %%
# %cd ../
# Out:
# /content

# %%
# !cp -r HarDNet-MSEG/ drive/MyDrive/

# %%
# !python eval_Kvasir.py

# %%
# !cp -r ./snapshots/HarD-MSEG-best/ ../drive/MyDrive/

# %%
# !pip install --ignore-installed PyYAML
# Out:
# ...
#      |████████████████████████████████| 636 kB 7.3 MB/s
# ...

# %%
# !python Eval.py
# Out:
# #################### Start Evaluation ####################
# Expr - HarDMSEG:   0% 0/5 [00:00<?, ?it/s]
# CVC-300 - Evaluation:   0% 0/60 [00:00<?, ?it/s]
# CVC-300 - Evaluation:   2% 1/60 [00:02<02:21,  2.39s/it]
# CVC-300 - Evaluation:   3% 2/60 [00:04<02:20,  2.42s/it]
# CVC-300 - Evaluation:   5% 3/60 [00:06<02:11,  2.30s/it]
# CVC-300 - Evaluation:   7% 4/60 [00:09<02:06,  2.26s/it]
# CVC-300 - Evaluation:   8% 5/60 [00:11<02:02,  2.23s/it]
# CVC-300 - Evaluation:  10% 6/60 [00:13<01:58,  2.20s/it]
# CVC-300 - Evaluation:  12% 7/60 [00:15<01:55,  2.18s/it]
# CVC-300 - Evaluation:  13% 8/60 [00:17<01:52,  2.16s/it]
# CVC-300 - Evaluation:  15% 9/60 [00:19<01:50,  2.17s/it]
# CVC-300 - Evaluation:  17% 10/60 [00:22<01:47,  2.15s/it]
# CVC-300 - Evaluation:  18% 11/60 [00:24<01:44,  2.14s/it]
# CVC-300 - Evaluation:  20% 12/60 [00:26<01:41,  2.12s/it]
# CVC-300 - Evaluation:  22% 13/60 [00:28<01:39,  2.12s/it]
# CVC-300 - Evaluation:  23% 14/60 [00:30<01:37,  2.11s/it]
# ...
